# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = rasterio.open('../../Share_Data/satellite/cart_tif_file/203/download.classification.tif').read(1)

# %%
img.shape
# Out:
# (1045, 1045)

# %%
cart_img = img.

# %%
sum(sum(img==2))
# Out:
# 6856

# %%
Image.open('../../Share_Data/satellite/jpg_rgb_10/jpg_rgb_d10/203.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1045x1045 at 0x7F7F3D7B2E48>

# %%
plt.imshow(img)

# %%
Image.open('../../Share_Data/satellite/hillshape_d10/hillshape_d10/203az0.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1045x1045 at 0x7F7F3F0DB908>
