# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# * 이미지를 VAE로 Embedding하여 얻은 vector의 similarity와 풍속데이터의 Similarity 비교
# * 체크해야 할 것
#     - 풍속기록이 있는 데이터만 필요하며, 일부는 Train 일부는 test 이를 구분해야 할 필요가 있음

# %%
import pickle
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image

import yaml
import torch
from torchvision import transforms, datasets
from torch.utils.data import SubsetRandomSampler, DataLoader, TensorDataset

from src.hillshpaeDataModule import MySimCLRTrainDataTransform
from simCLR import *
from src import *

# %%
# Wind data load

with open('../../Share_Data/windspeed/_Main_dataset.pickle', 'rb') as f:
    windspeed_dataset = pickle.load(f)

station_list = list(windspeed_dataset.keys())
windspeed_list = []
for item in windspeed_dataset.values():
    windspeed_list.append(item[3])
windspeed_list = np.array(windspeed_list)

# %%
# load config
config_path = 'configs/simclr_rgb.yaml'
checkpoint_path = '../../Share_Data/logs/SimCLR_CART/last.ckpt'

with open(config_path, 'rb') as f:
    config = yaml.safe_load(f)

#load vae model
untrained_model = simclr_model[config['model_params']['name']](**config['model_params'], num_samples=10)
model = simclr_model[config['model_params']['name']](**config['model_params'], num_samples=10)

#checkpoint load
checkpoint = torch.load(checkpoint_path, map_location=torch.device('cpu')) # when using CPU
model.load_state_dict(checkpoint['state_dict'])
# Out:
# <All keys matched successfully>

# %%
# load img data
IMG_PATH = '../../Share_Data/satellite/jpg_cart_d10/_jpg_cart_d10/{}.jpg'

img_list =[ ]
label_list = []
for station_code in station_list:
    img = Image.open(IMG_PATH.format(station_code)).resize([config['exp_parmas']['img_size']]*2)
    img_list.append(np.array(img))
    label_list.append(station_code)

img_list = (np.array(img_list)/255.)*2-1
tensor_img = torch.Tensor(img_list).permute(0,3,1,2)
tensor_dataset = TensorDataset(tensor_img)
dataloader = DataLoader(tensor_dataset)

# %%
model_latent = model.forward(tensor_img)
untrained_latent = untrained_model.forward(tensor_img)

model_projection = model.Projection(model_latent)
untrained_model_projection = untrained_model.Projection(untrained_latent)

print('size of latent : {}'.format(model_latent.size()))
print('size of projection : {}'.format(model_projection.size()))
# Out:
# size of latent : torch.Size([349, 512, 4, 4])
# size of projection : torch.Size([349, 32])

# %% [markdown]
# ---
# # Analysis

# %%
#windspeed difference matrix

windspeed_diff_list = []
for i in windspeed_list:
    temp_list = []
    for j in windspeed_list:
        temp_list.append(abs(i-j))
    windspeed_diff_list.append(temp_list)
windspeed_diff_list = np.array(windspeed_diff_list)

# %%
model_n = model_projection.norm(dim=1)[:,None]
model_n = torch.max(model_n, 1e-8*torch.ones_like(model_n))

un_model_n = untrained_model_projection.norm(dim=1)[:, None]
un_model_n = torch.max(un_model_n, 1e-8*torch.ones_like(un_model_n))

cov = torch.mm(model_projection/model_n, (model_projection/model_n).t().contiguous())
sim = torch.exp(cov)
untrained_cov = torch.mm(untrained_model_projection/un_model_n, (untrained_model_projection/un_model_n).t().contiguous())
untrained_sim = torch.exp(untrained_cov)

windspeed_diff = np.exp(-windspeed_diff_list/windspeed_diff_list.max()+1)

plt.figure(figsize=(20,7))
plt.subplot(1,3,1)
plt.title('trained')
sns.heatmap(sim.detach().numpy())

plt.subplot(1,3,2)
plt.title('untrained')
sns.heatmap(untrained_sim.detach().numpy())

plt.subplot(1,3,3)
plt.title('windspeed')
sns.heatmap(windspeed_diff)
plt.show()

# %%
plt.figure(figsize=(20,7))
plt.subplot(1,3,1)
plt.title('trained-untrained')
sns.heatmap(abs(sim.detach().numpy()-untrained_sim.detach().numpy()))

plt.subplot(1,3,2)
plt.title('trained-windspeed')
sns.heatmap(abs(sim.detach().numpy()-windspeed_diff))

plt.subplot(1,3,3)
plt.title('untrained-windspeed')
sns.heatmap(abs(untrained_sim.detach().numpy()-windspeed_diff))
plt.show()

# %% [markdown]
# ## Contents
#
# * [Experiment 01](#Experiment_01) - Clustering으로 Labeling.
# * [Experiment 01_Detail_Labeling](#Detail_Labeling) - Labeling을 더욱 디테일하게
# * [Experiment 02](#Experiment_02) - Regression

# %% [markdown]
# ## Experiment_01
# * Clustering으로 labeling 비교해보자
#
# [go to contents](#Contents)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
with open('../../Share_Data/windspeed/rgb_d5_label.pickle', 'rb') as f:
    label = pickle.load(f)
    
label_pd = pd.DataFrame(label).set_index(0)

# %%
select_label = []
for i in list(windspeed_dataset):
    select_label.append(int(label_pd.loc[i][1]))

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(model_projection.detach().numpy())

# %% [markdown]
# * 눈으로 보기엔 4 <- 0 / 2<-2 / 3<-1 인듯

# %%
change_list = [4, 3, 2]
kmeans_label = list(map(lambda x:change_list[x], kmeans.labels_))

# %%
select_label = np.array(select_label).reshape(-1,1)
kmeans_label = np.array(kmeans_label).reshape(-1,1)

# %%
plt.figure(figsize=(20,5))
sns.heatmap(np.concatenate([select_label, kmeans_label], axis=-1).T)
plt.show()

# %%
print('difference : {}'.format(sum(select_label != kmeans_label)))
# Out:
# difference : [80]

# %%
sns.heatmap(confusion_matrix(select_label, kmeans_label),
            xticklabels=['B', 'C', 'D'],
            yticklabels=['B', 'C', 'D'],
            annot=True,
           cmap='gray')
plt.title('CART')
plt.ylabel('Human judgment')
plt.xlabel('Clustring result')
plt.show()

# %% [markdown]
# # Detail_Labeling
# * 각 센터가 해당 값일 때 거리에따라 weight sum

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(model_projection.detach().numpy())

# %%
center_4 = kmeans.cluster_centers_[0]
center_3 = kmeans.cluster_centers_[1]
center_2 = kmeans.cluster_centers_[2]

# %%
alpha_and_Zg = np.array([[0,0],[0.33, 500], [0.22, 400], [0.15, 300],[0.1, 250]])

def cal_coeff(x):
    dist_4 = np.linalg.norm(x-center_4)
    dist_3 = np.linalg.norm(x-center_3)
    dist_2 = np.linalg.norm(x-center_2)
    result = (alpha_and_Zg[2]/dist_2 + alpha_and_Zg[3]/dist_3 + alpha_and_Zg[4]/dist_4) / (1/dist_2+1/dist_3+1/dist_4)
    result[0] = max(min(0.22, result[0]), 0.1)
    result[1] = max(min(400, result[1]), 250)
    return result

# %%
select_label_ = np.array(list(map(lambda x : ['B', 'C', 'D'][int(x-2)],select_label.reshape(-1)))).reshape(-1,1)

# %%
new_coeff = np.array([cal_coeff(x) for x in model_projection.detach().numpy()])

# %%
data.dtypes
# Out:
# alpha     object
# Zg       float64
# label     object
# dtype: object

# %%
data.iloc[:,1]=data.iloc[:,1].astype(np.float64)

# %%
data = pd.DataFrame(np.concatenate([new_coeff, select_label_], axis=-1), 
                    columns=['alpha', 'Zg', 'label'])
data.iloc[:,1]=data.iloc[:,1].astype(np.float64)
data.iloc[:,0]=data.iloc[:,0].astype(np.float64)
plt.figure(figsize=(10,10))
sns.scatterplot(data=data, x='alpha', y='Zg', style='label', hue='label', palette="deep")
plt.show()

# %%
with open('../../Share_Data/windspeed/SimCLR_CART_newCoeff.pickle', 'wb') as f :
    pickle.dump(new_coeff, f)

# %% [markdown]
# ---
# ### 나름 의미 있는 결과 같은데,
# * RGB와 비교하면 더 좋아진거 같은데...
# * 2->4는 뭐지

# %%
# 휴리스틱하게 2번이라 분류했지만 기계가 1번이라고 답한거 둘러보자

select_inex = np.array(list(windspeed_dataset))[np.ravel((select_label == 3) & (kmeans_label==2))]
Sample_num = 10
row_num = 2
col_num = 5

fig_path = '../../Share_Data/satellite/jpg_cart_d10/_jpg_cart_d10/{}.jpg'

plt.figure(figsize=(15,5))
for index, img_name in enumerate(select_inex[:Sample_num]):
    plt.subplot(row_num, col_num, index+1)
    plt.imshow(Image.open(fig_path.format(img_name)))
    plt.axis('off')
plt.show()

# %%
# 2 -> 4

select_inex = np.array(list(windspeed_dataset))[np.ravel((select_label == 2) & (kmeans_label==4))]
Sample_num = 4
row_num = 1
col_num = 4

fig_path = '../../Share_Data/satellite/jpg_cart_d10/_jpg_cart_d10/{}.jpg'

plt.figure(figsize=(15,5))
for index, img_name in enumerate(select_inex[:Sample_num]):
    plt.subplot(row_num, col_num, index+1)
    plt.imshow(Image.open(fig_path.format(img_name)))
    plt.axis('off')
plt.show()

# %% [markdown]
# * 2->4 3번째는 뭐지

# %% [markdown]
# ### Classification 저장

# %%
with open('../../Share_Data/windspeed/change_Z_CART.pickle', 'wb') as f:
    pickle.dump(np.concatenate([select_label, kmeans_label], axis=-1),f)

# %% [markdown]
# ## Experiment_02
# * NN 사용하기 전에 LinearRegression
#
# * [go to contents](#Contents)

# %%
from sklearn import linear_model
from sklearn.metrics import explained_variance_score

# %%
# 위도와 경도 가져오자
place_list = pd.DataFrame(windspeed_dataset).T.iloc[:,0:2].to_numpy().astype(np.float32)
projection = model_projection.detach().numpy()

# 위도 경도 Normalize 하지 않고
total_list = np.concatenate([place_list, projection, np.array(windspeed_list).reshape(-1,1)], axis=-1)

# Random
random_index = np.random.permutation(len(total_list))

# %%
# data divide
ratio = 0.2

train_data = total_list[random_index[int(ratio*len(total_list)):]]
test_data = total_list[random_index[:int(ratio*len(total_list))]]

# %%
# Training

train_X = train_data[:,:-1]
train_Y = train_data[:,-1]
reg = linear_model.LinearRegression()
reg.fit(train_X, train_Y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([
#        28.79204892, 27.83881504, 26.24893036, 19.74907763, 19.95803507,
#        31.7782987 , 19.13317505, 17.76038249, 16.91556273, 21.22820661,
#        16.92745788, 18.99380897, 17.62729248, 16.93995259, 20.0949836 ,
#        20.89066893, 22.70750185, 28.77318529, 16.63909957, 14.20641524,
#        13.84236371, 12.88532078, 18.44908925, 38.61447928, 22.54922016,
#        22.36370211, 18.57823167, 12.57795241, 15.27061219, 17.04990351,
#        21.75711652, 15.76993614, 16.13699039, 25.66994194, 14.30195643,
#        14.9930911 , 10.55731786, 19.44963752, 15.8787694 , 14.15174343,
#        14.35562513, 17.38548096, 24.22672769, 26.83012684, 21.98596782,
#        18.88749835, 25.95137874, 14.72128201, 28.10546383, 21.86838501,
#        18.57290343, 18.76651868, 16.8898524 , 15.36010334, 19.13328389,
#        13.45096282, 20.75389286, 18.41452249, 24.7074698 , 15.39664447,
#        17.90563424, 14.44994171, 21.1214907 , 17.70013278, 21.98729808,
#        22.05553311, 18.8724932 , 19.68590506, 12.33065566, 16.76958164,
#        37.81822619, 17.44174003, 16.9716304 , 25.68033204, 15.73339644,
#        18.20843087, 21.05875116, 24.19832236, 13.86244108, 29.32968938,
#        18.16553346, 13.81312579, 16.16771541, 12.25122335, 24.0647625 ,
#        23.57181005, 17.57635138, 22.1518851 , 20.65765588, 16.67807956,
#        23.93027144, 19.30531278, 18.31313646, 13.77967819, 14.33070271,
#        14.98966763, 12.80359865, 28.09394242, 14.04476475, 16.45550135,
#        25.11559752, 19.1373675 , 18.74322921, 30.0773682 , 18.5785136 ,
#        15.7544475 , 18.29329098, 21.10953042, 22.84887392, 23.42114848,
#        27.42722497, 17.49560245, 25.51038256, 17.23459911, 21.65352522,
#        23.75266971, 18.80811289, 20.24846312, 18.3423378 , 22.19258329,
#        18.68126029, 19.52589337, 13.68768492, 13.39927287, 18.01445231,
#        19.87414329, 14.17049842, 14.8612901 , 16.4939519 , 23.33114233,
#        28.07335124, 12.49517535, 26.40188654, 22.46748365, 22.79417946,
#        19.06945667, 16.71580895, 15.6746029 , 19.38173926, 16.21285303,
#        13.82024151, 19.21613499, 18.0983085 , 25.95945442, 21.68382682,
#        14.0376988 , 17.39606389, 11.88473997, 16.9407457 , 17.11996109,
#        17.40577468, 17.66369183, 12.7413675 , 14.51501009, 18.31988904,
#        17.09776334, 19.09929531, 13.20316646, 16.5918599 , 11.7062704 ,
#        16.40430628, 17.45355653, 21.17645206, 19.73787798, 15.82742961,
#        16.80878888, 23.07441417, 36.08992022, 16.79739657, 19.69126717,
#        18.22124708, 13.5415065 , 22.4790666 , 20.17770199, 12.41044326,
#        15.7951828 , 20.78856736, 17.75063769,  9.96728961, 14.03447184])

# %%
# Predict

test_X = test_data[:,:-1]
test_Y = test_data[:,-1]
reg_result = reg.predict(test_X)

# %%
explained_variance_score(test_Y, reg_result)
# Out:
# 0.19240309790455956

# %% [markdown]
# * 드럽게 안됨
